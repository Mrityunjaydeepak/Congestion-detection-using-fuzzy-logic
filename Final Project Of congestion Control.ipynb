# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# %%
RTT=ctrl.Antecedent(np.arange(1,1000,100),'RTT')
RTT['low']=fuzzy.trimf(RTT.universe,(1,100,400))
RTT['medium']=fuzzy.trapmf(RTT.universe,[300,400,600,700])
RTT['high']=fuzzy.trapmf(RTT.universe,[600,800,1000,1000])
RTT.view()
plt.show()
# Out:
# C:\Users\mrity\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
RTT=ctrl.Antecedent(np.arange(1,1000,100),'RTT')
RTT['low']=fuzzy.trimf(RTT.universe,(1,100,400))
RTT['medium']=fuzzy.trapmf(RTT.universe,[300,400,600,700])
RTT['high']=fuzzy.trapmf(RTT.universe,[600,800,1000,1000])
RTT.view()
plt.show()
# Out:
# C:\Users\mrity\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
congestion=ctrl.Consequent(np.arange(0,20),'congestion')
congestion['Low']=fuzzy.trimf(congestion.universe,[1,1,4])
congestion['Medium']=fuzzy.trapmf(congestion.universe,[3,4,6,7])
congestion['High']=fuzzy.trapmf(congestion.universe,[6,8,10,10])
congestion.view()
plt.show()
# Out:
# C:\Users\mrity\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1=ctrl.Rule(RTT['low'] & Window['low'], congestion['Low'])
rule2=ctrl.Rule(RTT['low'] & Window['medium'], congestion['Low'])
rule3=ctrl.Rule(RTT['low'] & Window['high'], congestion['Medium'])
rule4=ctrl.Rule(RTT['medium'] & Window['low'], congestion['Low'])
rule5=ctrl.Rule(RTT['medium'] & Window['medium'], congestion['Medium'])
rule6=ctrl.Rule(RTT['medium'] & Window['high'], congestion['Medium'])
rule7=ctrl.Rule(RTT['high'] & Window['low'], congestion['Medium'])
rule8=ctrl.Rule(RTT['high'] & Window['medium'], congestion['Medium'])
rule9=ctrl.Rule(RTT['high'] & Window['high'], congestion['High'])
rule=[rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9]

# %%
x=ctrl.ControlSystem(rule)
y=ctrl.ControlSystemSimulation(x)

# %%
arr1= np.random.randint(1,1000, size=(100))
arr2= np.random.randint(1,1000, size=(100))
for indx in range(100):
    y.input['RTT']=arr1[indx]
   
    y.input['Window']=arr2[indx]
    y.compute()
    F=y.output['congestion']
    if(F>7.4):
        print("congestion  occured at",indx,"The Round Trip Time was:",arr1[indx],"The Window size was:",arr2[indx])
# Out:
# congestion  occured at 5 The Round Trip Time was: 840 The Window size was: 865
# congestion  occured at 6 The Round Trip Time was: 950 The Window size was: 355
# congestion  occured at 9 The Round Trip Time was: 678 The Window size was: 764
# congestion  occured at 15 The Round Trip Time was: 925 The Window size was: 429
# congestion  occured at 19 The Round Trip Time was: 697 The Window size was: 602
# congestion  occured at 21 The Round Trip Time was: 761 The Window size was: 50
# congestion  occured at 23 The Round Trip Time was: 943 The Window size was: 598
# congestion  occured at 26 The Round Trip Time was: 985 The Window size was: 428
# congestion  occured at 29 The Round Trip Time was: 995 The Window size was: 361
# congestion  occured at 31 The Round Trip Time was: 706 The Window size was: 658
# congestion  occured at 36 The Round Trip Time was: 888 The Window size was: 556
# congestion  occured at 38 The Round Trip Time was: 976 The Window size was: 199
# congestion  occured at 41 The Round Trip Time was: 955 The Window size was: 115
# congestion  occured at 46 The Round Trip Time was: 797 The Window size was: 60
# congestion  occured at 47 The Round Trip Time was: 684 The Window size was: 588
# congestion  occured at 58 The Round Trip Time was: 799 The Window size was: 960
# congestion  occured at 63 The Round Trip Time was: 776 The Window size was: 442
# congestion  occured at 71 The Round Trip Time was: 967 The Window size was: 958
# congestion  occured at 74 The Round Trip Time was: 972 The Window size was: 464
# congestion  occured at 75 The Round Trip Time was: 839 The Window size was: 772
# congestion  occured at 80 The Round Trip Time was: 996 The Window size was: 317
# congestion  occured at 90 The Round Trip Time was: 836 The Window size was: 421
# congestion  occured at 91 The Round Trip Time was: 981 The Window size was: 931
# congestion  occured at 92 The Round Trip Time was: 812 The Window size was: 677
# congestion  occured at 93 The Round Trip Time was: 864 The Window size was: 784
# congestion  occured at 94 The Round Trip Time was: 918 The Window size was: 350
# congestion  occured at 96 The Round Trip Time was: 695 The Window size was: 371
# congestion  occured at 98 The Round Trip Time was: 967 The Window size was: 241
# congestion  occured at 99 The Round Trip Time was: 783 The Window size was: 429
